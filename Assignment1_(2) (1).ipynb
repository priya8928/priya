# %%
#importing required librariees
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# LOAD THE DATASET

# %%
df = pd.read_csv('carinindia.csv')

# %%
df.head()
# Out:
#   ï»¿web-scraper-order                              web-scraper-start-url  \
# 0         1706437209-1  https://www.carwale.com/new/best-cars-under-20...
# 1         1706437211-2  https://www.carwale.com/new/best-cars-under-20...
# 2         1706437214-3  https://www.carwale.com/new/best-cars-under-20...
# 3         1706437216-4  https://www.carwale.com/new/best-cars-under-20...
# 4         1706437218-5  https://www.carwale.com/new/best-cars-under-20...
#
#                     Links                                         Links-href  \
# 0  Maruti Suzuki Alto K10  https://www.carwale.com/maruti-suzuki-cars/alt...
# 1  Maruti Suzuki S-Presso  https://www.carwale.com/maruti-suzuki-cars/s-p...
# 2            Renault Kwid         https://www.carwale.com/renault-cars/kwid/
# 3     Maruti Suzuki Ignis  https://www.carwale.com/maruti-suzuki-cars/ignis/
# 4      Maruti Suzuki Eeco   https://www.carwale.com/maruti-suzuki-cars/eeco/
#
# ...

# %%
df.tail()
# Out:
#    ï»¿web-scraper-order                              web-scraper-start-url  \
# 44        1706437321-45  https://www.carwale.com/new/best-cars-under-20...
# 45        1706437323-46  https://www.carwale.com/new/best-cars-under-20...
# 46        1706437325-47  https://www.carwale.com/new/best-cars-under-20...
# 47        1706437328-48  https://www.carwale.com/new/best-cars-under-20...
# 48        1706437330-49  https://www.carwale.com/new/best-cars-under-20...
#
#                     Links                                         Links-href  \
# 44        Mahindra XUV400      https://www.carwale.com/mahindra-cars/xuv400/
# 45  Toyota Innova Hycross  https://www.carwale.com/toyota-cars/innova-hyc...
# 46            Tata Safari          https://www.carwale.com/tata-cars/safari/
# 47   Toyota Innova Crysta  https://www.carwale.com/toyota-cars/innova-cry...
# 48           Tata Harrier         https://www.carwale.com/tata-cars/harrier/
#
# ...

# %%
df.shape
# Out:
# (49, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ï»¿web-scraper-order   49 non-null     object
#  1   web-scraper-start-url  49 non-null     object
#  2   Links                  49 non-null     object
#  3   Links-href             49 non-null     object
#  4   Name                   49 non-null     object
#  5   Price                  49 non-null     object
#  6   Mileage                23 non-null     object
#  7   Engine                 37 non-null     object
#  8   Safety                 19 non-null     object
#  9   Fuel Type              42 non-null     object
#  10  Transmission           42 non-null     object
#  11  Seating Capacity       42 non-null     object
#  12  Pages                  39 non-null     float64
#  13  Pages-href             39 non-null     object
# dtypes: float64(1), object(13)
# ...

# %%
df.isnull().any()
# Out:
# ï»¿web-scraper-order     False
# web-scraper-start-url    False
# Links                    False
# Links-href               False
# Name                     False
# Price                    False
# Mileage                   True
# Engine                    True
# Safety                    True
# Fuel Type                 True
# Transmission              True
# Seating Capacity          True
# Pages                     True
# Pages-href                True
# dtype: bool

# %%
df.Price.unique()
# Out:
# array(['Rs.  3.99 - 5.96 Lakh', 'Rs.  4.26 - 6.11 Lakh',
#        'Rs.  4.70 - 6.45 Lakh', 'Rs.  5.84 - 8.30 Lakh',
#        'Rs.  5.32 - 6.58 Lakh', 'Rs.  6.00 - 11.23 Lakh',
#        'Rs.  5.36 - 7.10 Lakh', 'Rs.  6.16 - 9.08 Lakh',
#        'Rs.  6.00 - 8.98 Lakh', 'Rs.  8.34 - 14.14 Lakh',
#        'Rs.  8.10 - 15.50 Lakh', 'Rs.  13.83 - 15.23 Lakh',
#        'Rs.  12.49 - 13.75 Lakh', 'Rs.  14.39 - 16.80 Lakh',
#        'Rs.  11.61 - 13.50 Lakh', 'Rs.  12.08 - 13.90 Lakh',
#        'Rs.  11.70 - 21.10 Lakh', 'Rs.  11.56 - 14.82 Lakh',
#        'Rs.  11.74 - 16.22 Lakh', 'Rs.  11.53 - 19.12 Lakh',
#        'Rs.  14.74 - 19.94 Lakh', 'Rs.  10.74 - 15.05 Lakh',
#        'Rs.  11.89 - 20.49 Lakh', 'Rs.  10.45 - 19.45 Lakh',
#        'Rs.  11.56 - 19.41 Lakh', 'Rs.  11.68 - 16.50 Lakh',
#        'Rs.  10.29 - 13.68 Lakh', 'Rs.  11.00 - 17.42 Lakh',
#        'Rs.  15.00 - 22.20 Lakh', 'Rs.  11.14 - 20.19 Lakh',
#        'Rs.  10.90 - 20.30 Lakh', 'Rs.  13.59 - 17.35 Lakh',
# ...

# %%
df.Pages.value_counts()
# Out:
# 4.0    10
# 3.0    10
# 2.0    10
# 8.0     9
# Name: Pages, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-17-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#        Pages
# Pages    1.0

# %% [markdown]
# visualisation
#
# UNIVARIATE ANALYSIS

# %%
sns.displot(df.Pages)

# %%
sns.displot(df.Mileage)

# %%
sns.barplot(x=df.Pages.value_counts().index,y=df.Pages.value_counts())
# Out:
# <Axes: xlabel='None', ylabel='Pages'>

# %%
sns.barplot(x=df.Price.value_counts().index,y=df.Price.value_counts())
# Out:
# <Axes: xlabel='None', ylabel='Price'>

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
sns.lineplot(x=df.Name,y=df.Pages)
# Out:
# <Axes: xlabel='Name', ylabel='Pages'>

# %%
sns.scatterplot(x=df.Name,y=df.Pages)
# Out:
# <Axes: xlabel='Name', ylabel='Pages'>

# %%
sns.lineplot(x=df.Name,y=df.Price)
# Out:
# <Axes: xlabel='Name', ylabel='Price'>

# %%
df.sample()
# Out:
#   ï»¿web-scraper-order                              web-scraper-start-url  \
# 3         1706437216-4  https://www.carwale.com/new/best-cars-under-20...
#
#                  Links                                         Links-href  \
# 3  Maruti Suzuki Ignis  https://www.carwale.com/maruti-suzuki-cars/ignis/
#
#            Name                  Price     Mileage   Engine Safety Fuel Type  \
# 3  Maruti Ignis  Rs.  5.84 - 8.30 Lakh  20.89 kmpl  1197 cc    NaN    Petrol
#
#          Transmission Seating Capacity  Pages  \
# 3  Manual & Automatic         5 Seater    8.0
#
#                                           Pages-href
# 3  https://www.carwale.com/new/best-cars-under-20...

# %%
df.columns
# Out:
# Index(['ï»¿web-scraper-order', 'web-scraper-start-url', 'Links', 'Links-href',
#        'Name', 'Price', 'Mileage', 'Engine', 'Safety', 'Fuel Type',
#        'Transmission', 'Seating Capacity', 'Pages', 'Pages-href'],
#       dtype='object')

# %%
con1 = df['Links']=='Maruti Suzuki Ignis'

# %%
df1 = df[con1]

# %%
df1
# Out:
#   ï»¿web-scraper-order                              web-scraper-start-url  \
# 3         1706437216-4  https://www.carwale.com/new/best-cars-under-20...
#
#                  Links                                         Links-href  \
# 3  Maruti Suzuki Ignis  https://www.carwale.com/maruti-suzuki-cars/ignis/
#
#            Name                  Price     Mileage   Engine Safety Fuel Type  \
# 3  Maruti Ignis  Rs.  5.84 - 8.30 Lakh  20.89 kmpl  1197 cc    NaN    Petrol
#
#          Transmission Seating Capacity  Pages  \
# 3  Manual & Automatic         5 Seater    8.0
#
#                                           Pages-href
# 3  https://www.carwale.com/new/best-cars-under-20...

# %%
df
# Out:
#    ï»¿web-scraper-order                              web-scraper-start-url  \
# 0          1706437209-1  https://www.carwale.com/new/best-cars-under-20...
# 1          1706437211-2  https://www.carwale.com/new/best-cars-under-20...
# 2          1706437214-3  https://www.carwale.com/new/best-cars-under-20...
# 3          1706437216-4  https://www.carwale.com/new/best-cars-under-20...
# 4          1706437218-5  https://www.carwale.com/new/best-cars-under-20...
# 5          1706437221-6  https://www.carwale.com/new/best-cars-under-20...
# 6          1706437223-7  https://www.carwale.com/new/best-cars-under-20...
# 7          1706437226-8  https://www.carwale.com/new/best-cars-under-20...
# 8          1706437228-9  https://www.carwale.com/new/best-cars-under-20...
# 9         1706437233-10  https://www.carwale.com/new/best-cars-under-20...
# 10        1706437235-11  https://www.carwale.com/new/best-cars-under-20...
# ...
